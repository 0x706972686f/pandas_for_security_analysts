# %% [markdown]
# Lets get started by importing the python libraries we need

# %%
import pandas as pd
from datetime import datetime, timezone, timedelta, time, date

# %% [markdown]
# Next we can read in the JSON file containing the events of interest. Obviously this is a cleaner situation for easier analysis, and sometimes the Pandas Dataframe stage can be a difficult one if the data source isn't normalised

# %%
df = pd.read_json('cmd_psexec_lsa_secrets_dump_2020-10-1903305471.json', lines=True)

# %% [markdown]
# We can get an idea of the data we've imported using the shape below, we can see it's 286 rows, by 119 columns

# %%
df.shape
# Out:
# (286, 119)

# %% [markdown]
# Using the head function we can see the top 5 rows:

# %%
df.head(5)
# Out:
#                             SourceName              TimeCreated      Hostname  \
# 0           Microsoft-Windows-Eventlog  2020-10-19 03:30:41.104  WORKSTATION5
# 1  Microsoft-Windows-Security-Auditing  2020-10-19 03:30:45.323  WORKSTATION5
# 2  Microsoft-Windows-Security-Auditing  2020-10-19 03:30:45.324  WORKSTATION5
# 3  Microsoft-Windows-Security-Auditing  2020-10-19 03:30:46.251  WORKSTATION5
# 4  Microsoft-Windows-Security-Auditing  2020-10-19 03:30:46.330  WORKSTATION5
#
#     Task   Channel                                            Message  \
# 0    104  Security  The audit log was cleared.\r\nSubject:\r\n\tSe...
# 1  12810  Security  The Windows Filtering Platform has permitted a...
# 2  12810  Security  The Windows Filtering Platform has permitted a...
# 3  13312  Security  A new process has been created.\r\n\r\nCreator...
# 4  12807  Security  An attempt was made to duplicate a handle to a...
#
#    EventID  FilterRTID  SourcePort SourceAddress  ... DestinationPort  \
# 0     1102         NaN         NaN           NaN  ...             NaN
# 1     5158         0.0     58390.0       0.0.0.0  ...             NaN
# 2     5156     69895.0     58390.0   192.168.2.5  ...             NaN
# 3     4688         NaN         NaN           NaN  ...             NaN
# 4     4690         NaN         NaN           NaN  ...             NaN
#
#   SourceIsIpv6  SourceHostname Initiated QueryName QueryStatus QueryResults  \
# 0          NaN             NaN       NaN       NaN         NaN          NaN
# 1          NaN             NaN       NaN       NaN         NaN          NaN
# 2          NaN             NaN       NaN       NaN         NaN          NaN
# 3          NaN             NaN       NaN       NaN         NaN          NaN
# 4          NaN             NaN       NaN       NaN         NaN          NaN
#
#   StartType AccountName  ImagePath
# 0       NaN         NaN        NaN
# 1       NaN         NaN        NaN
# 2       NaN         NaN        NaN
# 3       NaN         NaN        NaN
# 4       NaN         NaN        NaN
#
# [5 rows x 118 columns]

# %% [markdown]
# If we examine the `TimeCreated` field specifically, we can see that it's of type `O` - indicating it's an object

# %%
df.TimeCreated.dtype
# Out:
# dtype('O')

# %% [markdown]
# We can have a look at the specific column of the top 5 rows:

# %%
df['TimeCreated'].head(5)
# Out:
# 0    2020-10-19 03:30:41.104
# 1    2020-10-19 03:30:45.323
# 2    2020-10-19 03:30:45.324
# 3    2020-10-19 03:30:46.251
# 4    2020-10-19 03:30:46.330
# Name: TimeCreated, dtype: object

# %% [markdown]
# We can manually select a specific time to show the rows on

# %%
df[df['TimeCreated'] == '2020-10-19 03:30:41.104']
# Out:
#                    SourceName              TimeCreated      Hostname  Task  \
# 0  Microsoft-Windows-Eventlog  2020-10-19 03:30:41.104  WORKSTATION5   104
#
#     Channel                                            Message  EventID  \
# 0  Security  The audit log was cleared.\r\nSubject:\r\n\tSe...     1102
#
#    FilterRTID  SourcePort SourceAddress  ... DestinationPort SourceIsIpv6  \
# 0         NaN         NaN           NaN  ...             NaN          NaN
#
#    SourceHostname Initiated QueryName QueryStatus QueryResults StartType  \
# 0             NaN       NaN       NaN         NaN          NaN       NaN
#
#   AccountName  ImagePath
# 0         NaN        NaN
#
# [1 rows x 118 columns]

# %% [markdown]
# And we can filter further, selecting all rows where between the range of values

# %%
df[(df['TimeCreated'] >= '2020-10-19 03:30:40') & (df['TimeCreated'] <= '2020-10-19 03:30:42')]
# Out:
#                                                   SourceName  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  Microsoft-Windows-Eventlog
# 2020-10-19 03:30:41.150000+00:00  Microsoft-Windows-Eventlog
#
#                                               TimeCreated      Hostname  Task  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  2020-10-19 03:30:41.104  WORKSTATION5   104
# 2020-10-19 03:30:41.150000+00:00  2020-10-19 03:30:41.150  WORKSTATION5   104
#
#                                    Channel  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  Security
# 2020-10-19 03:30:41.150000+00:00    System
#
#                                                                             Message  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  The audit log was cleared.\r\nSubject:\r\n\tSe...
# 2020-10-19 03:30:41.150000+00:00                   The System log file was cleared.
#
#                                   EventID  FilterRTID  SourcePort  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00     1102         NaN         NaN
# 2020-10-19 03:30:41.150000+00:00      104         NaN         NaN
#
#                                  SourceAddress  ... SourceIsIpv6  \
# timestamp                                       ...
# 2020-10-19 03:30:41.104000+00:00           NaN  ...          NaN
# 2020-10-19 03:30:41.150000+00:00           NaN  ...          NaN
#
#                                  SourceHostname  Initiated QueryName  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00            NaN        NaN       NaN
# 2020-10-19 03:30:41.150000+00:00            NaN        NaN       NaN
#
#                                  QueryStatus QueryResults StartType  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:41.150000+00:00         NaN          NaN       NaN
#
#                                  AccountName ImagePath  interesting
# timestamp
# 2020-10-19 03:30:41.104000+00:00         NaN       NaN         True
# 2020-10-19 03:30:41.150000+00:00         NaN       NaN         True
#
# [2 rows x 119 columns]

# %% [markdown]
# The problem with the `TimeCreated` column though is it's an `object`, they have special operations they can do on the objects, but they're a little larger. Dataframes have a special type called `datetime64` which recognises that it's a timestamp and can let us do more time based operations.
#
# We can convert the object to a `datetime64` type and set it as the index, sorting it at the same time below:

# %%
df.index = pd.to_datetime(df['TimeCreated'],format="%Y-%m-%d %H:%M:%S.%f").dt.tz_localize('UTC')
df.index.names = ['timestamp']
df.sort_index(inplace=True)
df.head(5)
# Out:
#                                                   SourceName  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  Microsoft-Windows-Eventlog
# 2020-10-19 03:30:41.150000+00:00  Microsoft-Windows-Eventlog
# 2020-10-19 03:30:42.058000+00:00    Microsoft-Windows-Sysmon
# 2020-10-19 03:30:42.851000+00:00    Microsoft-Windows-Sysmon
# 2020-10-19 03:30:42.851000+00:00    Microsoft-Windows-Sysmon
#
#                                               TimeCreated      Hostname  Task  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  2020-10-19 03:30:41.104  WORKSTATION5   104
# 2020-10-19 03:30:41.150000+00:00  2020-10-19 03:30:41.150  WORKSTATION5   104
# 2020-10-19 03:30:42.058000+00:00  2020-10-19 03:30:42.058  WORKSTATION5    11
# 2020-10-19 03:30:42.851000+00:00  2020-10-19 03:30:42.851  WORKSTATION5    12
# 2020-10-19 03:30:42.851000+00:00  2020-10-19 03:30:42.851  WORKSTATION5    13
#
#                                                                Channel  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00                              Security
# 2020-10-19 03:30:41.150000+00:00                                System
# 2020-10-19 03:30:42.058000+00:00  Microsoft-Windows-Sysmon/Operational
# 2020-10-19 03:30:42.851000+00:00  Microsoft-Windows-Sysmon/Operational
# 2020-10-19 03:30:42.851000+00:00  Microsoft-Windows-Sysmon/Operational
#
#                                                                             Message  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  The audit log was cleared.\r\nSubject:\r\n\tSe...
# 2020-10-19 03:30:41.150000+00:00                   The System log file was cleared.
# 2020-10-19 03:30:42.058000+00:00  File created:\r\nRuleName: -\r\nUtcTime: 2020-...
# 2020-10-19 03:30:42.851000+00:00  Registry object added or deleted:\r\nRuleName:...
# 2020-10-19 03:30:42.851000+00:00  Registry value set:\r\nRuleName: -\r\nEventTyp...
#
#                                   EventID  FilterRTID  SourcePort  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00     1102         NaN         NaN
# 2020-10-19 03:30:41.150000+00:00      104         NaN         NaN
# 2020-10-19 03:30:42.058000+00:00       11         NaN         NaN
# 2020-10-19 03:30:42.851000+00:00       12         NaN         NaN
# 2020-10-19 03:30:42.851000+00:00       13         NaN         NaN
#
#                                  SourceAddress  ... SourceIsIpv6  \
# timestamp                                       ...
# 2020-10-19 03:30:41.104000+00:00           NaN  ...          NaN
# 2020-10-19 03:30:41.150000+00:00           NaN  ...          NaN
# 2020-10-19 03:30:42.058000+00:00           NaN  ...          NaN
# 2020-10-19 03:30:42.851000+00:00           NaN  ...          NaN
# 2020-10-19 03:30:42.851000+00:00           NaN  ...          NaN
#
#                                  SourceHostname  Initiated QueryName  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00            NaN        NaN       NaN
# 2020-10-19 03:30:41.150000+00:00            NaN        NaN       NaN
# 2020-10-19 03:30:42.058000+00:00            NaN        NaN       NaN
# 2020-10-19 03:30:42.851000+00:00            NaN        NaN       NaN
# 2020-10-19 03:30:42.851000+00:00            NaN        NaN       NaN
#
#                                  QueryStatus QueryResults StartType  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:41.150000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:42.058000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:42.851000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:42.851000+00:00         NaN          NaN       NaN
#
#                                  AccountName ImagePath  interesting
# timestamp
# 2020-10-19 03:30:41.104000+00:00         NaN       NaN         True
# 2020-10-19 03:30:41.150000+00:00         NaN       NaN         True
# 2020-10-19 03:30:42.058000+00:00         NaN       NaN         True
# 2020-10-19 03:30:42.851000+00:00         NaN       NaN         True
# 2020-10-19 03:30:42.851000+00:00         NaN       NaN         True
#
# [5 rows x 119 columns]

# %% [markdown]
# We can confirm that the index is now the proper `datetime64` type below:

# %%
df.index.dtype
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# And we can use built in `DateTime` functions to simplify or programmatically query the times like below:

# %%
df.loc[time(3,30,40):time(3,30,42)]
# Out:
#                                                   SourceName  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  Microsoft-Windows-Eventlog
# 2020-10-19 03:30:41.150000+00:00  Microsoft-Windows-Eventlog
#
#                                               TimeCreated      Hostname  Task  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  2020-10-19 03:30:41.104  WORKSTATION5   104
# 2020-10-19 03:30:41.150000+00:00  2020-10-19 03:30:41.150  WORKSTATION5   104
#
#                                    Channel  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  Security
# 2020-10-19 03:30:41.150000+00:00    System
#
#                                                                             Message  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  The audit log was cleared.\r\nSubject:\r\n\tSe...
# 2020-10-19 03:30:41.150000+00:00                   The System log file was cleared.
#
#                                   EventID  FilterRTID  SourcePort  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00     1102         NaN         NaN
# 2020-10-19 03:30:41.150000+00:00      104         NaN         NaN
#
#                                  SourceAddress  ... SourceIsIpv6  \
# timestamp                                       ...
# 2020-10-19 03:30:41.104000+00:00           NaN  ...          NaN
# 2020-10-19 03:30:41.150000+00:00           NaN  ...          NaN
#
#                                  SourceHostname  Initiated QueryName  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00            NaN        NaN       NaN
# 2020-10-19 03:30:41.150000+00:00            NaN        NaN       NaN
#
#                                  QueryStatus QueryResults StartType  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:41.150000+00:00         NaN          NaN       NaN
#
#                                  AccountName ImagePath  interesting
# timestamp
# 2020-10-19 03:30:41.104000+00:00         NaN       NaN         True
# 2020-10-19 03:30:41.150000+00:00         NaN       NaN         True
#
# [2 rows x 119 columns]

# %% [markdown]
# Because our index is the times and it's sorted, we can see the starting and end time below

# %%
df.iloc[[0,-1]]
# Out:
#                                                   SourceName  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  Microsoft-Windows-Eventlog
# 2020-10-19 03:30:53.402000+00:00    Microsoft-Windows-Sysmon
#
#                                               TimeCreated      Hostname  Task  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  2020-10-19 03:30:41.104  WORKSTATION5   104
# 2020-10-19 03:30:53.402000+00:00  2020-10-19 03:30:53.402  WORKSTATION5    13
#
#                                                                Channel  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00                              Security
# 2020-10-19 03:30:53.402000+00:00  Microsoft-Windows-Sysmon/Operational
#
#                                                                             Message  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00  The audit log was cleared.\r\nSubject:\r\n\tSe...
# 2020-10-19 03:30:53.402000+00:00  Registry value set:\r\nRuleName: -\r\nEventTyp...
#
#                                   EventID  FilterRTID  SourcePort  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00     1102         NaN         NaN
# 2020-10-19 03:30:53.402000+00:00       13         NaN         NaN
#
#                                  SourceAddress  ... SourceIsIpv6  \
# timestamp                                       ...
# 2020-10-19 03:30:41.104000+00:00           NaN  ...          NaN
# 2020-10-19 03:30:53.402000+00:00           NaN  ...          NaN
#
#                                  SourceHostname  Initiated QueryName  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00            NaN        NaN       NaN
# 2020-10-19 03:30:53.402000+00:00            NaN        NaN       NaN
#
#                                  QueryStatus QueryResults StartType  \
# timestamp
# 2020-10-19 03:30:41.104000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:53.402000+00:00         NaN          NaN       NaN
#
#                                  AccountName ImagePath  interesting
# timestamp
# 2020-10-19 03:30:41.104000+00:00         NaN       NaN         True
# 2020-10-19 03:30:53.402000+00:00         NaN       NaN          NaN
#
# [2 rows x 119 columns]

# %% [markdown]
# The advantage to doing this is programmatically being able to filter things. If we had a bigger data set that could span over multiple days we could filter down working hours, or other things.
#
# Below we're highlighting a 7 second window, indicating that these events are of interest, while the rest are not

# %%
day = date(2020,10,19)
starting_time = time(3,30,40)
ending_time = time(3,30,47)
start_time = datetime.combine(day, starting_time).replace(tzinfo=timezone.utc)
end_time = datetime.combine(day, ending_time).replace(tzinfo=timezone.utc)

df_interesting_events = (df.index > start_time) & (df.index <= end_time)
df.loc[df_interesting_events,'interesting'] = True
df.loc[~df_interesting_events,'interesting'] = False

# %% [markdown]
# We can then quickly see how many items appear to be 'of interest'

# %%
df[['interesting']].value_counts()
# Out:
# interesting
# True           260
# False           26
# dtype: int64

# %% [markdown]
# We can also group and count different fields, which can be a useful mechanism for identifying rare items, or highlighting common items that might not be useful in your analysis

# %%
df[['EventID','SourceName']].value_counts()
# Out:
# EventID  SourceName
# 7        Microsoft-Windows-Sysmon               130
# 10       Microsoft-Windows-Sysmon                38
# 13       Microsoft-Windows-Sysmon                23
# 12       Microsoft-Windows-Sysmon                14
# 4658     Microsoft-Windows-Security-Auditing      8
# 11       Microsoft-Windows-Sysmon                 7
# 17       Microsoft-Windows-Sysmon                 7
# 18       Microsoft-Windows-Sysmon                 7
# 1        Microsoft-Windows-Sysmon                 4
# 5156     Microsoft-Windows-Security-Auditing      4
# 4690     Microsoft-Windows-Security-Auditing      4
# 4689     Microsoft-Windows-Security-Auditing      4
# 4688     Microsoft-Windows-Security-Auditing      4
# 4663     Microsoft-Windows-Security-Auditing      4
# 4703     Microsoft-Windows-Security-Auditing      4
# 4656     Microsoft-Windows-Security-Auditing      4
# 5        Microsoft-Windows-Sysmon                 4
# 5158     Microsoft-Windows-Security-Auditing      3
# 9        Microsoft-Windows-Sysmon                 3
# 3        Microsoft-Windows-Sysmon                 2
# 22       Microsoft-Windows-Sysmon                 2
# 5145     Microsoft-Windows-Security-Auditing      1
# 1102     Microsoft-Windows-Eventlog               1
# 5140     Microsoft-Windows-Security-Auditing      1
# 4697     Microsoft-Windows-Security-Auditing      1
# 104      Microsoft-Windows-Eventlog               1
# 7045     Service Control Manager                  1
# dtype: int64

# %% [markdown]
# We can also identify fields that may not have any values or content

# %%
df[df['SourceHostname'].notnull()]
# Out:
#                                                 SourceName  \
# timestamp
# 2020-10-19 03:30:47.681000+00:00  Microsoft-Windows-Sysmon
# 2020-10-19 03:30:47.681000+00:00  Microsoft-Windows-Sysmon
#
#                                               TimeCreated      Hostname  Task  \
# timestamp
# 2020-10-19 03:30:47.681000+00:00  2020-10-19 03:30:47.681  WORKSTATION5     3
# 2020-10-19 03:30:47.681000+00:00  2020-10-19 03:30:47.681  WORKSTATION5     3
#
#                                                                Channel  \
# timestamp
# 2020-10-19 03:30:47.681000+00:00  Microsoft-Windows-Sysmon/Operational
# 2020-10-19 03:30:47.681000+00:00  Microsoft-Windows-Sysmon/Operational
#
#                                                                             Message  \
# timestamp
# 2020-10-19 03:30:47.681000+00:00  Network connection detected:\r\nRuleName: -\r\...
# 2020-10-19 03:30:47.681000+00:00  Network connection detected:\r\nRuleName: -\r\...
#
#                                   EventID  FilterRTID  SourcePort  \
# timestamp
# 2020-10-19 03:30:47.681000+00:00        3         NaN     58391.0
# 2020-10-19 03:30:47.681000+00:00        3         NaN     58391.0
#
#                                  SourceAddress  ... SourceIsIpv6  \
# timestamp                                       ...
# 2020-10-19 03:30:47.681000+00:00           NaN  ...         true
# 2020-10-19 03:30:47.681000+00:00           NaN  ...         true
#
#                                  SourceHostname  Initiated QueryName  \
# timestamp
# 2020-10-19 03:30:47.681000+00:00              -       true       NaN
# 2020-10-19 03:30:47.681000+00:00              -      false       NaN
#
#                                  QueryStatus QueryResults StartType  \
# timestamp
# 2020-10-19 03:30:47.681000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:47.681000+00:00         NaN          NaN       NaN
#
#                                  AccountName ImagePath  interesting
# timestamp
# 2020-10-19 03:30:47.681000+00:00         NaN       NaN          NaN
# 2020-10-19 03:30:47.681000+00:00         NaN       NaN          NaN
#
# [2 rows x 119 columns]

# %% [markdown]
# It's possible to create complex filters, looking for different values in different rows

# %%
mask_operational_log_event_id_1 = (df['Channel'] == 'Microsoft-Windows-Sysmon/Operational') & (df['EventID'] == 1)
df[mask_operational_log_event_id_1]
# Out:
#                                                 SourceName  \
# timestamp
# 2020-10-19 03:30:46.257000+00:00  Microsoft-Windows-Sysmon
# 2020-10-19 03:30:46.438000+00:00  Microsoft-Windows-Sysmon
# 2020-10-19 03:30:46.663000+00:00  Microsoft-Windows-Sysmon
# 2020-10-19 03:30:46.674000+00:00  Microsoft-Windows-Sysmon
#
#                                               TimeCreated      Hostname  Task  \
# timestamp
# 2020-10-19 03:30:46.257000+00:00  2020-10-19 03:30:46.257  WORKSTATION5     1
# 2020-10-19 03:30:46.438000+00:00  2020-10-19 03:30:46.438  WORKSTATION5     1
# 2020-10-19 03:30:46.663000+00:00  2020-10-19 03:30:46.663  WORKSTATION5     1
# 2020-10-19 03:30:46.674000+00:00  2020-10-19 03:30:46.674  WORKSTATION5     1
#
#                                                                Channel  \
# timestamp
# 2020-10-19 03:30:46.257000+00:00  Microsoft-Windows-Sysmon/Operational
# 2020-10-19 03:30:46.438000+00:00  Microsoft-Windows-Sysmon/Operational
# 2020-10-19 03:30:46.663000+00:00  Microsoft-Windows-Sysmon/Operational
# 2020-10-19 03:30:46.674000+00:00  Microsoft-Windows-Sysmon/Operational
#
#                                                                             Message  \
# timestamp
# 2020-10-19 03:30:46.257000+00:00  Process Create:\r\nRuleName: -\r\nUtcTime: 202...
# 2020-10-19 03:30:46.438000+00:00  Process Create:\r\nRuleName: -\r\nUtcTime: 202...
# 2020-10-19 03:30:46.663000+00:00  Process Create:\r\nRuleName: -\r\nUtcTime: 202...
# 2020-10-19 03:30:46.674000+00:00  Process Create:\r\nRuleName: -\r\nUtcTime: 202...
#
#                                   EventID  FilterRTID  SourcePort  \
# timestamp
# 2020-10-19 03:30:46.257000+00:00        1         NaN         NaN
# 2020-10-19 03:30:46.438000+00:00        1         NaN         NaN
# 2020-10-19 03:30:46.663000+00:00        1         NaN         NaN
# 2020-10-19 03:30:46.674000+00:00        1         NaN         NaN
#
#                                  SourceAddress  ... SourceIsIpv6  \
# timestamp                                       ...
# 2020-10-19 03:30:46.257000+00:00           NaN  ...          NaN
# 2020-10-19 03:30:46.438000+00:00           NaN  ...          NaN
# 2020-10-19 03:30:46.663000+00:00           NaN  ...          NaN
# 2020-10-19 03:30:46.674000+00:00           NaN  ...          NaN
#
#                                  SourceHostname  Initiated QueryName  \
# timestamp
# 2020-10-19 03:30:46.257000+00:00            NaN        NaN       NaN
# 2020-10-19 03:30:46.438000+00:00            NaN        NaN       NaN
# 2020-10-19 03:30:46.663000+00:00            NaN        NaN       NaN
# 2020-10-19 03:30:46.674000+00:00            NaN        NaN       NaN
#
#                                  QueryStatus QueryResults StartType  \
# timestamp
# 2020-10-19 03:30:46.257000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:46.438000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:46.663000+00:00         NaN          NaN       NaN
# 2020-10-19 03:30:46.674000+00:00         NaN          NaN       NaN
#
#                                  AccountName ImagePath  interesting
# timestamp
# 2020-10-19 03:30:46.257000+00:00         NaN       NaN         True
# 2020-10-19 03:30:46.438000+00:00         NaN       NaN         True
# 2020-10-19 03:30:46.663000+00:00         NaN       NaN         True
# 2020-10-19 03:30:46.674000+00:00         NaN       NaN         True
#
# [4 rows x 119 columns]

# %% [markdown]
# This can then be taken further, we can create a mask that is a Pandas series which returns the index values where a condition is met. We can then use boolean logic to combine them together to create more complex queries.
#
# Below we're looking where `psexesvc` is in the `ImagePath` column, or `Interesting` is `True`, but not where `EventID` is set to 7.

# %%
mask_psexec = df['ImagePath'].str.contains('PSEXESVC', na=False, case=False)
mask_event_id_7 = df['EventID'].astype(str) == '7'
mask_interesting = df['AccountName'] == 'LocalSystem'
df[(mask_psexec|mask_interesting)&~mask_event_id_7]
# Out:
#                                                SourceName  \
# timestamp
# 2020-10-19 03:30:46.416000+00:00  Service Control Manager
#
#                                               TimeCreated      Hostname  Task  \
# timestamp
# 2020-10-19 03:30:46.416000+00:00  2020-10-19 03:30:46.416  WORKSTATION5     0
#
#                                  Channel  \
# timestamp
# 2020-10-19 03:30:46.416000+00:00  System
#
#                                                                             Message  \
# timestamp
# 2020-10-19 03:30:46.416000+00:00  A service was installed in the system.\r\n\r\n...
#
#                                   EventID  FilterRTID  SourcePort  \
# timestamp
# 2020-10-19 03:30:46.416000+00:00     7045         NaN         NaN
#
#                                  SourceAddress  ... SourceIsIpv6  \
# timestamp                                       ...
# 2020-10-19 03:30:46.416000+00:00           NaN  ...          NaN
#
#                                  SourceHostname  Initiated QueryName  \
# timestamp
# 2020-10-19 03:30:46.416000+00:00            NaN        NaN       NaN
#
#                                  QueryStatus QueryResults     StartType  \
# timestamp
# 2020-10-19 03:30:46.416000+00:00         NaN          NaN  demand start
#
#                                   AccountName                  ImagePath  \
# timestamp
# 2020-10-19 03:30:46.416000+00:00  LocalSystem  %SystemRoot%\PSEXESVC.exe
#
#                                   interesting
# timestamp
# 2020-10-19 03:30:46.416000+00:00         True
#
# [1 rows x 119 columns]

# %% [markdown]
# When looking at a timeline we may not necessarily know where to start because of the sheer volume of data. To help with that we can group data together based on a timeframe to try and provide an indicator of where we look.
#
# By grouping the `EventID` into a 3 second window, we can see that the majority of events happen around `03:30:45`

# %%
df['EventID'].groupby(pd.Grouper(freq='3S')).value_counts()
# Out:
# timestamp                  EventID
# 2020-10-19 03:30:39+00:00  104          1
#                            1102         1
# 2020-10-19 03:30:42+00:00  10          14
#                            13           5
#                            11           1
#                            12           1
# 2020-10-19 03:30:45+00:00  7          130
#                            12          13
#                            13          12
#                            10          10
#                            4658         8
#                            17           7
#                            18           7
#                            11           6
#                            1            4
#                            5            4
#                            4656         4
#                            4663         4
#                            4688         4
#                            4689         4
#                            4690         4
#                            4703         4
#                            5156         4
#                            9            3
#                            5158         3
#                            3            2
#                            4697         1
#                            5140         1
#                            5145         1
#                            7045         1
# 2020-10-19 03:30:48+00:00  10          14
#                            13           4
#                            22           2
# 2020-10-19 03:30:51+00:00  13           2
# Name: EventID, dtype: int64
